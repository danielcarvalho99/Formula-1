# %%
import fastf1

# %%
from google.cloud import storage

client = storage.Client.from_service_account_json("bucket-access.json")
bucket = client.bucket("bucket-f1-data")
blob = bucket.blob("bronze/test.csv")
blob.upload_from_filename("test.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 6
#       2
#       3 client = storage.Client.from_service_account_json("bucket-access.json")
#       4 bucket = client.bucket("bucket-f1-data")
#       5 blob = bucket.blob("bronze/test.csv")
# ----> 6 blob.upload_from_filename("test.csv")
#
# File ~/Documents/Formula-1/.venv/lib/python3.12/site-packages/google/cloud/storage/blob.py:3198, in Blob.upload_from_filename(self, filename, content_type, client, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, crc32c_checksum_value)
#    3071 """Upload this blob's contents from the content of a named file.
#    3072
#    3073 The content type of the upload will be determined in order
#    (...)   3195     base64: https://datatracker.ietf.org/doc/html/rfc4648#section-4
# ...

# %%
from extractor import Extractor
extractor = Extractor(years=[2021,2022], modes=['R'])
extractor.process_year_mode(year=2021, mode='R')
# Out:
# req         WARNING 	DEFAULT CACHE ENABLED! (99.47 MB) /home/daniel/.cache/fastf1
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for driver_info
# ...

# %%
from client import GCPClient
gcp_client = GCPClient("bucket-access.json")
client = gcp_client.authenticate()

# %%
from writer import Writer
writer = Writer(client)
files = writer.list_files(path="data/", extension=".csv")

for file in files:
    writer.write_to_bucket(local_file_path=f"data/{file}", gcp_file_path=f"bronze/races/{file}", bucket_name="bucket-f1-data")
# Out:
# 2021_08_R.csv
# 2021_09_R.csv
# 2021_21_R.csv
# 2021_01_R.csv
# 2021_17_R.csv
# 2021_14_R.csv
# 2021_13_R.csv
# 2021_07_R.csv
# 2021_19_R.csv
# 2021_04_R.csv
# 2021_20_R.csv
# 2021_06_R.csv
# 2021_16_R.csv
# 2021_18_R.csv
# 2021_03_R.csv
# 2021_10_R.csv
# 2021_12_R.csv
# 2021_22_R.csv
# 2021_15_R.csv
# 2021_05_R.csv
# 2021_11_R.csv
# 2021_02_R.csv
